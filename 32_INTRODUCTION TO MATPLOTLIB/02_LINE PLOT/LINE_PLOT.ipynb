# %%
import matplotlib.pyplot as plt

# %%
x=["day1","day2","day3","day4","day5"]
y=[300,500,550,200,250]

# %%
plt.plot(x,y)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("placement (1).csv")

# %%
print(data)
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
plt.plot(data["cgpa"],data["placement"],marker="D")
plt.show(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27352\1049596823.py in ?()
#       1 plt.plot(data["cgpa"],data["placement"],marker="D")
# ----> 2 plt.show(data)
#
# ~\AppData\Roaming\Python\Python313\site-packages\matplotlib\pyplot.py in ?(*args, **kwargs)
#     610     the end of every cell by default. Thus, you usually don't have to call it
#     611     explicitly there.
#     612     """
#     613     _warn_if_gui_out_of_main_thread()
# --> 614     return _get_backend_mod().show(*args, **kwargs)
#
# ~\AppData\Roaming\Python\Python313\site-packages\matplotlib_inline\backend_inline.py in ?(close, block)
#      94     finally:
#      95         show._to_draw = []
#      96         # only call close('all') if any to close
#      97         # close triggers gc.collect, which can be slow
# ---> 98         if close and Gcf.get_all_fig_managers():
# ...
